# %% [markdown]
# # 신경망 생성
# - `torch.nn` 패키지 사용
#
# - `nn.Module`을 상속받고, 해당 모듈은 계층과 `output`을 반환하는 `forward`메소드를 포함
#
# - 파이토치에서 신경망 생성을 위한 기본 틀
#
#       1. class Net(nn.Module):
#
#            def __init__(self):
#                super(Net, self).__init__()
#
#       2. class MyModel(nn.Module):
#
#             def __init__(self):
#                 super(MyModel, self).__init__()
#
# - `conv2d` 레이어를 쌓을 때, 필터의 갯수를 계산하고 `in_channels`에 넣어줘야함

# %% [markdown]
# ## 신경망 정의

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.conv1 = nn.Conv2d(1, 6, 3)
        self.conv2 = nn.Conv2d(6, 16, 3)
        self.fc1 = nn.Linear(16 * 6 * 6, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), (2, 2))
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        x = x.view(-1, self.num_flat_features(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)

        return x
    
    def num_flat_features(self, x):
        size = x.size()[1:]
        num_features = 1
        
        for s in size:
            num_features *= s

        return num_features

net = Net()

net
# Out:
# Net(
#   (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=576, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %% [markdown]
# # 선형회귀(Linear Regression) 모델 생성
# - 코드 출처 : https://yceffort.kr/2019/02/19/pytorch-02-linear-regression/

# %% [markdown]
# ## modules import

# %%
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-white')

# %% [markdown]
# ## 데이터 생성 및 회귀식 설정

# %%
x = torch.randn(100, 1) * 10
y = x + 3 * torch.randn(100, 1)

plt.plot(x.numpy(), y.numpy(), 'o')

plt.ylabel('y')
plt.xlabel('x')
plt.grid()

plt.show()

# %% [markdown]
# ## 신경망 구성

# %%
class LinearRegressionModel(nn.Module):
    
    def __init__(self):
        super(LinearRegressionModel, self).__init__()
        self.linear = nn.Linear(1, 1)
    
    def forward(self, x):
        pred = self.linear(x)
        
        return pred

# %% [markdown]
# ## 모델 생성 및 파라미터 확인

# %%
torch.manual_seed(111)

model = LinearRegressionModel()

model
# Out:
# LinearRegressionModel(
#   (linear): Linear(in_features=1, out_features=1, bias=True)
# )

# %%
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[0.4311]], requires_grad=True),
#  Parameter containing:
#  tensor([0.8280], requires_grad=True)]

# %%
w, b = model.parameters()

def get_params():
    return w[0][0].item(), b[0].item()

def plot_fit(title):
    plt.title = title
    
    w1, b1 = get_params()
    x1 = np.array([-30, 30])
    y1 = w1 * x1 + b1
    
    plt.plot(x1, y1, 'r')
    plt.scatter(x, y)

    plt.show()
    
plot_fit('Initial Model')

# %% [markdown]
# ## 손실함수와 옵티마이저

# %%
criterion = nn.MSELoss()
optimizer = optim.SGD(params=model.parameters(), lr=0.001)

# %% [markdown]
# ## 모델 학습

# %%
epochs = 100
losses = []

for epoch in range(epochs):
    optimizer.zero_grad()
    
    y_pred = model(x)
    loss = criterion(y_pred, y)
    losses.append(loss.detach())
    loss.backward()
    
    optimizer.step()
    
    if epoch % 10 == 0:
        print(f"Epochs: {epoch:3d}, Loss:{loss:.4f}")
# Out:
# Epochs:   0, Loss:30.8448
# Epochs:  10, Loss:10.0786
# Epochs:  20, Loss:9.6737
# Epochs:  30, Loss:9.6427
# Epochs:  40, Loss:9.6194
# Epochs:  50, Loss:9.5971
# Epochs:  60, Loss:9.5758
# Epochs:  70, Loss:9.5553
# Epochs:  80, Loss:9.5355
# Epochs:  90, Loss:9.5166

# %% [markdown]
# ## 시각화

# %%
plt.plot(range(epochs), losses)

plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.show()

# %%
plot_fit('Trained Model')
