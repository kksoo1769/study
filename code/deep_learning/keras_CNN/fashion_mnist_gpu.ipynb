# %% [markdown]
# # 케라스 CNN Fashion MNIST

# %% [markdown]
# #### module import

# %%
# %load_ext tensorboard

# %%
import datetime
import numpy as np
import tensorflow as tf
import tensorflow.keras as tf
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-white')

from keras.models import Model, Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPool2D, Dropout, Input
from keras.utils import to_categorical
from keras.datasets.fashion_mnist import load_data
from keras.preprocessing.image import ImageDataGenerator
# Out:
# 2024-01-15 13:33:24.997622: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-15 13:33:24.997691: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-15 13:33:25.043140: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-15 13:33:25.126603: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-15 13:33:26.241591: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### 데이터 로드 및 전처리

# %%
(x_train, y_train), (x_test, y_test) = load_data()

x_train = x_train[..., np.newaxis]
x_test = x_test[..., np.newaxis]

x_train = x_train / 255
x_test = x_test / 255

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)
# (60000,)
# (10000,)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle Boot']

# %% [markdown]
# ### 모델 구성 및 컴파일
# - 임의의 모델

# %%
def build_model():
    model = Sequential()

    inp = Input(shape=(28, 28, 1))
    out = Conv2D(filters=32, kernel_size=(3, 3))(inp)
    out = Conv2D(filters=64, kernel_size=(3, 3))(out)
    out = Flatten()(out)
    out = Dense(units=128, activation='relu')(out)
    out = Dense(units=64, activation='relu')(out)
    out = Dense(units=10, activation='softmax')(out)

    model = Model(inputs=inp, outputs=out)

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

model_1 = build_model()

model_1.summary()
# Out:
# 2024-01-15 13:33:28.356024: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:23:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-15 13:33:28.503618: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:23:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-15 13:33:28.503665: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:23:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-15 13:33:28.505381: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:23:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-15 13:33:28.505418: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:23:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-15 13:33:28.505450: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:23:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-15 13:33:28.751677: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:23:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-15 13:33:28.751860: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:23:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-15 13:33:28.751868: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-01-15 13:33:28.751901: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:23:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-15 13:33:28.751919: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5606 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:23:00.0, compute capability: 8.6
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        18496
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dense (Dense)               (None, 128)               4718720
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 4746442 (18.11 MB)
# Trainable params: 4746442 (18.11 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습
# - 런타임 GPU로 설정

# %%
hist_1 = model_1.fit(
    x_train, y_train,
    epochs=50,
    batch_size=128,
    validation_split=.3
)
# Out:
# Epoch 1/50
# 2024-01-15 13:33:30.150936: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2024-01-15 13:33:30.410256: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-01-15 13:33:30.909341: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-01-15 13:33:30.992748: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fb0083573b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-01-15 13:33:30.992926: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Ti, Compute Capability 8.6
# 2024-01-15 13:33:31.011591: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1705293211.136288    4970 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 329/329 [==============================] - 7s 12ms/step - loss: 0.4901 - accuracy: 0.8262 - val_loss: 0.3841 - val_accuracy: 0.8629
# Epoch 2/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.3256 - accuracy: 0.8805 - val_loss: 0.3549 - val_accuracy: 0.8741
# Epoch 3/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.2676 - accuracy: 0.9001 - val_loss: 0.3492 - val_accuracy: 0.8757
# Epoch 4/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.2252 - accuracy: 0.9165 - val_loss: 0.3890 - val_accuracy: 0.8683
# Epoch 5/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.1840 - accuracy: 0.9313 - val_loss: 0.4136 - val_accuracy: 0.8653
# Epoch 6/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.1566 - accuracy: 0.9429 - val_loss: 0.4442 - val_accuracy: 0.8707
# Epoch 7/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.1384 - accuracy: 0.9499 - val_loss: 0.4801 - val_accuracy: 0.8767
# Epoch 8/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.1116 - accuracy: 0.9592 - val_loss: 0.5668 - val_accuracy: 0.8620
# Epoch 9/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.1038 - accuracy: 0.9614 - val_loss: 0.5437 - val_accuracy: 0.8614
# Epoch 10/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0877 - accuracy: 0.9675 - val_loss: 0.6442 - val_accuracy: 0.8677
# Epoch 11/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0820 - accuracy: 0.9696 - val_loss: 0.6602 - val_accuracy: 0.8678
# Epoch 12/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0697 - accuracy: 0.9746 - val_loss: 0.6868 - val_accuracy: 0.8652
# Epoch 13/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0685 - accuracy: 0.9749 - val_loss: 0.7250 - val_accuracy: 0.8709
# Epoch 14/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0574 - accuracy: 0.9798 - val_loss: 0.7820 - val_accuracy: 0.8674
# Epoch 15/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0595 - accuracy: 0.9791 - val_loss: 0.8665 - val_accuracy: 0.8654
# Epoch 16/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0490 - accuracy: 0.9828 - val_loss: 0.8606 - val_accuracy: 0.8647
# Epoch 17/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0459 - accuracy: 0.9839 - val_loss: 0.8871 - val_accuracy: 0.8652
# Epoch 18/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0454 - accuracy: 0.9846 - val_loss: 0.9103 - val_accuracy: 0.8663
# Epoch 19/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0433 - accuracy: 0.9855 - val_loss: 0.9762 - val_accuracy: 0.8690
# Epoch 20/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0309 - accuracy: 0.9892 - val_loss: 1.0444 - val_accuracy: 0.8607
# Epoch 21/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0446 - accuracy: 0.9845 - val_loss: 1.0385 - val_accuracy: 0.8622
# Epoch 22/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0442 - accuracy: 0.9847 - val_loss: 0.9907 - val_accuracy: 0.8694
# Epoch 23/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0337 - accuracy: 0.9883 - val_loss: 1.0694 - val_accuracy: 0.8623
# Epoch 24/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0273 - accuracy: 0.9904 - val_loss: 1.1586 - val_accuracy: 0.8641
# Epoch 25/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0342 - accuracy: 0.9882 - val_loss: 1.1830 - val_accuracy: 0.8631
# Epoch 26/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0310 - accuracy: 0.9897 - val_loss: 1.1213 - val_accuracy: 0.8636
# Epoch 27/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0256 - accuracy: 0.9912 - val_loss: 1.1698 - val_accuracy: 0.8620
# Epoch 28/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0301 - accuracy: 0.9899 - val_loss: 1.2336 - val_accuracy: 0.8634
# Epoch 29/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0359 - accuracy: 0.9890 - val_loss: 1.2156 - val_accuracy: 0.8641
# Epoch 30/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0317 - accuracy: 0.9895 - val_loss: 1.1823 - val_accuracy: 0.8697
# Epoch 31/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0234 - accuracy: 0.9926 - val_loss: 1.2230 - val_accuracy: 0.8652
# Epoch 32/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0196 - accuracy: 0.9933 - val_loss: 1.2400 - val_accuracy: 0.8669
# Epoch 33/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0162 - accuracy: 0.9949 - val_loss: 1.3325 - val_accuracy: 0.8614
# Epoch 34/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0371 - accuracy: 0.9883 - val_loss: 1.2944 - val_accuracy: 0.8634
# Epoch 35/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0299 - accuracy: 0.9904 - val_loss: 1.3017 - val_accuracy: 0.8648
# Epoch 36/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0185 - accuracy: 0.9939 - val_loss: 1.3437 - val_accuracy: 0.8639
# Epoch 37/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0255 - accuracy: 0.9915 - val_loss: 1.3490 - val_accuracy: 0.8651
# Epoch 38/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 1.3665 - val_accuracy: 0.8677
# Epoch 39/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0282 - accuracy: 0.9911 - val_loss: 1.4469 - val_accuracy: 0.8604
# Epoch 40/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0246 - accuracy: 0.9920 - val_loss: 1.4278 - val_accuracy: 0.8674
# Epoch 41/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0210 - accuracy: 0.9933 - val_loss: 1.4278 - val_accuracy: 0.8668
# Epoch 42/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0149 - accuracy: 0.9950 - val_loss: 1.4738 - val_accuracy: 0.8658
# Epoch 43/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0224 - accuracy: 0.9926 - val_loss: 1.4692 - val_accuracy: 0.8574
# Epoch 44/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0217 - accuracy: 0.9928 - val_loss: 1.4929 - val_accuracy: 0.8667
# Epoch 45/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0207 - accuracy: 0.9933 - val_loss: 1.4613 - val_accuracy: 0.8647
# Epoch 46/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0280 - accuracy: 0.9916 - val_loss: 1.4842 - val_accuracy: 0.8613
# Epoch 47/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0192 - accuracy: 0.9934 - val_loss: 1.5029 - val_accuracy: 0.8672
# Epoch 48/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0225 - accuracy: 0.9929 - val_loss: 1.5950 - val_accuracy: 0.8645
# Epoch 49/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 1.7198 - val_accuracy: 0.8614
# Epoch 50/50
# 329/329 [==============================] - 3s 9ms/step - loss: 0.0250 - accuracy: 0.9926 - val_loss: 1.5524 - val_accuracy: 0.8646

# %% [markdown]
# ### 학습 결과 시각화

# %%
hist_1_dict = hist_1.history

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(hist_1_dict['loss'], 'b--', label='loss')
plt.plot(hist_1_dict['val_loss'], 'r:', label='val_loss')
plt.xlabel("Epochs")
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(hist_1_dict['accuracy'], 'b--', label='accuracy')
plt.plot(hist_1_dict['val_accuracy'], 'r:', label='val_accuracy')
plt.xlabel("Epochs")
plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# ### 모델 평가

# %%
model_1.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.6721 - accuracy: 0.8557
# [1.6721056699752808, 0.8557000160217285]

# %% [markdown]
# ### 모델 재구성
# - 학습 파라미터의 수 비교

# %%
def build_model2():
    model = Sequential()

    inp = Input(shape=(28, 28, 1))
    out = Conv2D(filters=32, kernel_size=(3, 3))(inp)
    out = MaxPool2D(strides=(2, 2))(out)
    out = Conv2D(filters=64, kernel_size=(3, 3))(out)
    out = MaxPool2D(strides=(2, 2))(out)
    out = Flatten()(out)
    out = Dense(units=128, activation='relu')(out)
    out = Dropout(0.3)(out)
    out = Dense(units=64, activation='relu')(out)
    out = Dropout(0.3)(out)
    out = Dense(units=10, activation='softmax')(out)

    model = Model(inputs=inp, outputs=out)

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

model_2 = build_model2()

model_2.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dense_3 (Dense)             (None, 128)               204928
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 232650 (908.79 KB)
# Trainable params: 232650 (908.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 모델 재학습

# %%
hist_2 = model_2.fit(
    x_train, y_train,
    epochs=50,
    batch_size=128,
    validation_split=.3
)
# Out:
# Epoch 1/50
# 329/329 [==============================] - 5s 9ms/step - loss: 0.7851 - accuracy: 0.7192 - val_loss: 0.4628 - val_accuracy: 0.8244
# Epoch 2/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.4847 - accuracy: 0.8291 - val_loss: 0.3777 - val_accuracy: 0.8638
# Epoch 3/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.4105 - accuracy: 0.8544 - val_loss: 0.3514 - val_accuracy: 0.8716
# Epoch 4/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.3688 - accuracy: 0.8696 - val_loss: 0.3266 - val_accuracy: 0.8774
# Epoch 5/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.3408 - accuracy: 0.8781 - val_loss: 0.3032 - val_accuracy: 0.8919
# Epoch 6/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.3145 - accuracy: 0.8878 - val_loss: 0.2989 - val_accuracy: 0.8931
# Epoch 7/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.2937 - accuracy: 0.8944 - val_loss: 0.3012 - val_accuracy: 0.8917
# Epoch 8/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.2824 - accuracy: 0.8982 - val_loss: 0.2808 - val_accuracy: 0.8982
# Epoch 9/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.2640 - accuracy: 0.9038 - val_loss: 0.2957 - val_accuracy: 0.8912
# Epoch 10/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.2512 - accuracy: 0.9089 - val_loss: 0.2745 - val_accuracy: 0.9012
# Epoch 11/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.2370 - accuracy: 0.9134 - val_loss: 0.2874 - val_accuracy: 0.8993
# Epoch 12/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.2281 - accuracy: 0.9164 - val_loss: 0.2684 - val_accuracy: 0.9057
# Epoch 13/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.2120 - accuracy: 0.9216 - val_loss: 0.2769 - val_accuracy: 0.9045
# Epoch 14/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.2050 - accuracy: 0.9235 - val_loss: 0.2878 - val_accuracy: 0.9070
# Epoch 15/50
# 329/329 [==============================] - 2s 8ms/step - loss: 0.1932 - accuracy: 0.9288 - val_loss: 0.2764 - val_accuracy: 0.9084
# Epoch 16/50
# 329/329 [==============================] - 2s 8ms/step - loss: 0.1867 - accuracy: 0.9302 - val_loss: 0.2825 - val_accuracy: 0.9073
# Epoch 17/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.1782 - accuracy: 0.9334 - val_loss: 0.2996 - val_accuracy: 0.9032
# Epoch 18/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1654 - accuracy: 0.9384 - val_loss: 0.2866 - val_accuracy: 0.9086
# Epoch 19/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1614 - accuracy: 0.9404 - val_loss: 0.2921 - val_accuracy: 0.9097
# Epoch 20/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1556 - accuracy: 0.9413 - val_loss: 0.2852 - val_accuracy: 0.9098
# Epoch 21/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1472 - accuracy: 0.9455 - val_loss: 0.3055 - val_accuracy: 0.9067
# Epoch 22/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1381 - accuracy: 0.9475 - val_loss: 0.2980 - val_accuracy: 0.9090
# Epoch 23/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1309 - accuracy: 0.9517 - val_loss: 0.3180 - val_accuracy: 0.9094
# Epoch 24/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1272 - accuracy: 0.9530 - val_loss: 0.3054 - val_accuracy: 0.9106
# Epoch 25/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1226 - accuracy: 0.9543 - val_loss: 0.3411 - val_accuracy: 0.9106
# Epoch 26/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1196 - accuracy: 0.9551 - val_loss: 0.3290 - val_accuracy: 0.9112
# Epoch 27/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1132 - accuracy: 0.9590 - val_loss: 0.3314 - val_accuracy: 0.9122
# Epoch 28/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1108 - accuracy: 0.9585 - val_loss: 0.3487 - val_accuracy: 0.9083
# Epoch 29/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1029 - accuracy: 0.9611 - val_loss: 0.3853 - val_accuracy: 0.9063
# Epoch 30/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1059 - accuracy: 0.9600 - val_loss: 0.3785 - val_accuracy: 0.9123
# Epoch 31/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0978 - accuracy: 0.9640 - val_loss: 0.3883 - val_accuracy: 0.9097
# Epoch 32/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0964 - accuracy: 0.9644 - val_loss: 0.3717 - val_accuracy: 0.9099
# Epoch 33/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0913 - accuracy: 0.9654 - val_loss: 0.3621 - val_accuracy: 0.9110
# Epoch 34/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0917 - accuracy: 0.9655 - val_loss: 0.3858 - val_accuracy: 0.9096
# Epoch 35/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0850 - accuracy: 0.9686 - val_loss: 0.3941 - val_accuracy: 0.9107
# Epoch 36/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0829 - accuracy: 0.9696 - val_loss: 0.4022 - val_accuracy: 0.9114
# Epoch 37/50
# 329/329 [==============================] - 2s 8ms/step - loss: 0.0785 - accuracy: 0.9712 - val_loss: 0.4078 - val_accuracy: 0.9103
# Epoch 38/50
# 329/329 [==============================] - 2s 8ms/step - loss: 0.0788 - accuracy: 0.9713 - val_loss: 0.4089 - val_accuracy: 0.9088
# Epoch 39/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0801 - accuracy: 0.9706 - val_loss: 0.4547 - val_accuracy: 0.9089
# Epoch 40/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0771 - accuracy: 0.9714 - val_loss: 0.4392 - val_accuracy: 0.9091
# Epoch 41/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0752 - accuracy: 0.9724 - val_loss: 0.3907 - val_accuracy: 0.9102
# Epoch 42/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0731 - accuracy: 0.9736 - val_loss: 0.4227 - val_accuracy: 0.9102
# Epoch 43/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0678 - accuracy: 0.9754 - val_loss: 0.4218 - val_accuracy: 0.9092
# Epoch 44/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0649 - accuracy: 0.9768 - val_loss: 0.4499 - val_accuracy: 0.9098
# Epoch 45/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0698 - accuracy: 0.9751 - val_loss: 0.4189 - val_accuracy: 0.9090
# Epoch 46/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0629 - accuracy: 0.9768 - val_loss: 0.4564 - val_accuracy: 0.9092
# Epoch 47/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0668 - accuracy: 0.9765 - val_loss: 0.4339 - val_accuracy: 0.9107
# Epoch 48/50
# 329/329 [==============================] - 2s 8ms/step - loss: 0.0661 - accuracy: 0.9771 - val_loss: 0.4559 - val_accuracy: 0.9095
# Epoch 49/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0699 - accuracy: 0.9754 - val_loss: 0.4752 - val_accuracy: 0.9079
# Epoch 50/50
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0594 - accuracy: 0.9777 - val_loss: 0.4848 - val_accuracy: 0.9064

# %%
hist_2_dict = hist_2.history

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(hist_2_dict['loss'], 'b--', label='loss')
plt.plot(hist_2_dict['val_loss'], 'r:', label='val_loss')
plt.xlabel("Epochs")
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(hist_2_dict['accuracy'], 'b--', label='accuracy')
plt.plot(hist_2_dict['val_accuracy'], 'r:', label='val_accuracy')
plt.xlabel("Epochs")
plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# ### 모델 재평가

# %%
model_2.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5002 - accuracy: 0.9027
# [0.5002214312553406, 0.9027000069618225]

# %% [markdown]
# ## 모델 성능 높이기 - 많은 레이어 쌓기

# %%
from keras.layers import BatchNormalization, ReLU

# %%
def build_model3():
    model = Sequential()

    inp = Input(shape=(28, 28, 1))
    out = Conv2D(filters=32, kernel_size=(3, 3), activation=ReLU(), padding='same')(inp)
    out = Conv2D(filters=64, kernel_size=(3, 3), activation=ReLU(), padding='valid')(inp)
    out = MaxPool2D(strides=(2, 2))(out)
    out = Dropout(0.5)(out)

    out = Conv2D(filters=128, kernel_size=(3, 3), activation=ReLU(), padding='same')(out)
    out = Conv2D(filters=256, kernel_size=(3, 3), activation=ReLU(), padding='valid')(out)
    out = MaxPool2D(strides=(2, 2))(out)
    out = Dropout(0.5)(out)

    out = Flatten()(out)
    out = Dense(units=256, activation='relu')(out)
    out = Dropout(0.5)(out)
    out = Dense(units=100, activation='relu')(out)
    out = Dropout(0.5)(out)
    out = Dense(units=10, activation='softmax')(out)

    model = Model(inputs=inp, outputs=out)

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

model_3 = build_model3()

model_3.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_5 (Conv2D)           (None, 26, 26, 64)        640
#
#  max_pooling2d_2 (MaxPoolin  (None, 13, 13, 64)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 13, 13, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 13, 13, 128)       73856
#
#  conv2d_7 (Conv2D)           (None, 11, 11, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 5, 5, 256)         0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 5, 5, 256)         0
#
#  flatten_2 (Flatten)         (None, 6400)              0
#
#  dense_6 (Dense)             (None, 256)               1638656
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 100)               25700
#
#  dropout_5 (Dropout)         (None, 100)               0
#
#  dense_8 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 2035030 (7.76 MB)
# Trainable params: 2035030 (7.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 모델 학습 및 결과 시각화

# %%
hist_3 = model_3.fit(
    x_train, y_train,
    epochs=50,
    batch_size=128,
    validation_split=.3
)
# Out:
# Epoch 1/50
# 2024-01-15 13:38:07.136252: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_2/dropout_2/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 329/329 [==============================] - 8s 15ms/step - loss: 0.8564 - accuracy: 0.6854 - val_loss: 0.4454 - val_accuracy: 0.8350
# Epoch 2/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.4910 - accuracy: 0.8270 - val_loss: 0.3327 - val_accuracy: 0.8754
# Epoch 3/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.4095 - accuracy: 0.8567 - val_loss: 0.3183 - val_accuracy: 0.8811
# Epoch 4/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.3690 - accuracy: 0.8685 - val_loss: 0.2897 - val_accuracy: 0.8941
# Epoch 5/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.3463 - accuracy: 0.8781 - val_loss: 0.2721 - val_accuracy: 0.9021
# Epoch 6/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.3309 - accuracy: 0.8846 - val_loss: 0.2587 - val_accuracy: 0.9064
# Epoch 7/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.3122 - accuracy: 0.8890 - val_loss: 0.2652 - val_accuracy: 0.9031
# Epoch 8/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.2974 - accuracy: 0.8926 - val_loss: 0.2391 - val_accuracy: 0.9136
# Epoch 9/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.2841 - accuracy: 0.9006 - val_loss: 0.2529 - val_accuracy: 0.9096
# Epoch 10/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.2791 - accuracy: 0.8994 - val_loss: 0.2377 - val_accuracy: 0.9141
# Epoch 11/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.2747 - accuracy: 0.9020 - val_loss: 0.2369 - val_accuracy: 0.9122
# Epoch 12/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.2626 - accuracy: 0.9062 - val_loss: 0.2317 - val_accuracy: 0.9179
# Epoch 13/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.2512 - accuracy: 0.9101 - val_loss: 0.2215 - val_accuracy: 0.9201
# Epoch 14/50
# 329/329 [==============================] - 4s 14ms/step - loss: 0.2506 - accuracy: 0.9107 - val_loss: 0.2389 - val_accuracy: 0.9139
# Epoch 15/50
# 329/329 [==============================] - 4s 14ms/step - loss: 0.2426 - accuracy: 0.9132 - val_loss: 0.2222 - val_accuracy: 0.9207
# Epoch 16/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.2414 - accuracy: 0.9133 - val_loss: 0.2238 - val_accuracy: 0.9193
# Epoch 17/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.2303 - accuracy: 0.9180 - val_loss: 0.2170 - val_accuracy: 0.9221
# Epoch 18/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.2283 - accuracy: 0.9179 - val_loss: 0.2246 - val_accuracy: 0.9214
# Epoch 19/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.2269 - accuracy: 0.9173 - val_loss: 0.2209 - val_accuracy: 0.9249
# Epoch 20/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.2182 - accuracy: 0.9196 - val_loss: 0.2179 - val_accuracy: 0.9270
# Epoch 21/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.2142 - accuracy: 0.9221 - val_loss: 0.2164 - val_accuracy: 0.9232
# Epoch 22/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.2110 - accuracy: 0.9235 - val_loss: 0.2141 - val_accuracy: 0.9248
# Epoch 23/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.2164 - accuracy: 0.9202 - val_loss: 0.2293 - val_accuracy: 0.9221
# Epoch 24/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.2036 - accuracy: 0.9255 - val_loss: 0.2149 - val_accuracy: 0.9228
# Epoch 25/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.2040 - accuracy: 0.9252 - val_loss: 0.2210 - val_accuracy: 0.9243
# Epoch 26/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.2018 - accuracy: 0.9273 - val_loss: 0.2180 - val_accuracy: 0.9263
# Epoch 27/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.2013 - accuracy: 0.9251 - val_loss: 0.2204 - val_accuracy: 0.9252
# Epoch 28/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1986 - accuracy: 0.9283 - val_loss: 0.2032 - val_accuracy: 0.9297
# Epoch 29/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1953 - accuracy: 0.9281 - val_loss: 0.2193 - val_accuracy: 0.9246
# Epoch 30/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1892 - accuracy: 0.9301 - val_loss: 0.2242 - val_accuracy: 0.9238
# Epoch 31/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.1886 - accuracy: 0.9303 - val_loss: 0.2134 - val_accuracy: 0.9268
# Epoch 32/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.1843 - accuracy: 0.9313 - val_loss: 0.2111 - val_accuracy: 0.9291
# Epoch 33/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.1860 - accuracy: 0.9319 - val_loss: 0.2070 - val_accuracy: 0.9304
# Epoch 34/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1836 - accuracy: 0.9333 - val_loss: 0.2075 - val_accuracy: 0.9311
# Epoch 35/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1796 - accuracy: 0.9330 - val_loss: 0.2184 - val_accuracy: 0.9276
# Epoch 36/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1817 - accuracy: 0.9333 - val_loss: 0.2117 - val_accuracy: 0.9299
# Epoch 37/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1827 - accuracy: 0.9341 - val_loss: 0.2417 - val_accuracy: 0.9154
# Epoch 38/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1867 - accuracy: 0.9310 - val_loss: 0.2163 - val_accuracy: 0.9290
# Epoch 39/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.1763 - accuracy: 0.9341 - val_loss: 0.2085 - val_accuracy: 0.9319
# Epoch 40/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1698 - accuracy: 0.9375 - val_loss: 0.2138 - val_accuracy: 0.9289
# Epoch 41/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.1709 - accuracy: 0.9372 - val_loss: 0.2215 - val_accuracy: 0.9267
# Epoch 42/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1684 - accuracy: 0.9376 - val_loss: 0.2166 - val_accuracy: 0.9319
# Epoch 43/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1685 - accuracy: 0.9378 - val_loss: 0.2159 - val_accuracy: 0.9312
# Epoch 44/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1652 - accuracy: 0.9396 - val_loss: 0.2059 - val_accuracy: 0.9314
# Epoch 45/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.1674 - accuracy: 0.9378 - val_loss: 0.2087 - val_accuracy: 0.9317
# Epoch 46/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.1647 - accuracy: 0.9390 - val_loss: 0.2101 - val_accuracy: 0.9318
# Epoch 47/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.1659 - accuracy: 0.9394 - val_loss: 0.2172 - val_accuracy: 0.9332
# Epoch 48/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.1659 - accuracy: 0.9391 - val_loss: 0.2070 - val_accuracy: 0.9321
# Epoch 49/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.1599 - accuracy: 0.9408 - val_loss: 0.2177 - val_accuracy: 0.9293
# Epoch 50/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.1583 - accuracy: 0.9433 - val_loss: 0.2144 - val_accuracy: 0.9306

# %% [markdown]
# - 과적합은 되지 않았지만 층을 늘려도 좋은 성능을 낼 수 있음

# %%
hist_3_dict = hist_3.history

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(hist_3_dict['loss'], 'b--', label='loss')
plt.plot(hist_3_dict['val_loss'], 'r:', label='val_loss')
plt.xlabel("Epochs")
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(hist_3_dict['accuracy'], 'b--', label='accuracy')
plt.plot(hist_3_dict['val_accuracy'], 'r:', label='val_accuracy')
plt.xlabel("Epochs")
plt.grid()
plt.legend()

plt.show()

# %%
model_3.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2412 - accuracy: 0.9237
# [0.24118860065937042, 0.9236999750137329]

# %% [markdown]
# ## 모델 성능 높이기 - 이미지 보강(Image Augmentation)
#
# - 주요 인자 참고: https://keras.io/ko/preprocessing/image/

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
img_geneartor = ImageDataGenerator(
    rotation_range=10, # 회전
    zoom_range=.2, # 확대
    shear_range=.6, # 밀리게
    width_shift_range=.1,
    height_shift_range=.1,
    horizontal_flip=True, # 수평 반전
    vertical_flip=False
)

# %%
augment_size = 200

# %%
print(x_train.shape)
print(x_train[0].shape)
# Out:
# (60000, 28, 28, 1)
# (28, 28, 1)

# %%
x_augment = img_geneartor.flow(
    np.tile(x_train[0].reshape(28 * 28 * 1), augment_size).reshape(-1, 28, 28, 1),
    np.zeros(augment_size),
    batch_size=augment_size,
    shuffle=False).next()[0]

# %%
plt.figure(figsize=(10, 10))

for i in range(1, 101):
    plt.subplot(10, 10, i)
    plt.axis('off')
    plt.imshow(x_augment[i - 1].reshape(28, 28), cmap='gray')

# %% [markdown]
# 데이터 추가

# %%
img_geneartor = ImageDataGenerator(
    rotation_range=15, # 회전
    zoom_range=.1, # 확대
    shear_range=.6, # 밀리게
    width_shift_range=.15,
    height_shift_range=.1,
    horizontal_flip=True, # 수평 반전
    vertical_flip=False
)

# %%
augment_size = 30_000

# %%
random_mask = np.random.randint(x_train.shape[0], size=augment_size)
x_augmented = x_train[random_mask].copy()
y_augmented = y_train[random_mask].copy()

# %%
x_augmented = img_geneartor.flow(
    x_augmented, np.zeros(augment_size),
    batch_size=augment_size, shuffle=False
).next()[0]

x_train = np.concatenate((x_train, x_augmented))
y_train = np.concatenate((y_train, y_augmented))

print(x_train.shape)
print(y_train.shape)
# Out:
# (90000, 28, 28, 1)
# (90000,)

# %% [markdown]
# ## 모델 학습 및 결과 시각화

# %%
model_4 = build_model3()

model_4.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_9 (Conv2D)           (None, 26, 26, 64)        640
#
#  max_pooling2d_4 (MaxPoolin  (None, 13, 13, 64)        0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 13, 13, 64)        0
#
#  conv2d_10 (Conv2D)          (None, 13, 13, 128)       73856
#
#  conv2d_11 (Conv2D)          (None, 11, 11, 256)       295168
#
#  max_pooling2d_5 (MaxPoolin  (None, 5, 5, 256)         0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 5, 5, 256)         0
#
#  flatten_3 (Flatten)         (None, 6400)              0
#
#  dense_9 (Dense)             (None, 256)               1638656
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 100)               25700
#
#  dropout_9 (Dropout)         (None, 100)               0
#
#  dense_11 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 2035030 (7.76 MB)
# Trainable params: 2035030 (7.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
hist_4 = model_4.fit(
    x_train, y_train,
    epochs=50,
    batch_size=128,
    validation_split=.3
)
# Out:
# Epoch 1/50
# 493/493 [==============================] - 7s 15ms/step - loss: 0.4556 - accuracy: 0.8383 - val_loss: 0.6440 - val_accuracy: 0.7518
# Epoch 2/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.3914 - accuracy: 0.8617 - val_loss: 0.5928 - val_accuracy: 0.7760
# Epoch 3/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.3588 - accuracy: 0.8725 - val_loss: 0.5916 - val_accuracy: 0.7764
# Epoch 4/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.3385 - accuracy: 0.8788 - val_loss: 0.5890 - val_accuracy: 0.7748
# Epoch 5/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.3209 - accuracy: 0.8875 - val_loss: 0.5588 - val_accuracy: 0.7863
# Epoch 6/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.3063 - accuracy: 0.8896 - val_loss: 0.5570 - val_accuracy: 0.7893
# Epoch 7/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2974 - accuracy: 0.8954 - val_loss: 0.5585 - val_accuracy: 0.7884
# Epoch 8/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2884 - accuracy: 0.8972 - val_loss: 0.5612 - val_accuracy: 0.7848
# Epoch 9/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2777 - accuracy: 0.8995 - val_loss: 0.5211 - val_accuracy: 0.8028
# Epoch 10/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2714 - accuracy: 0.9016 - val_loss: 0.5415 - val_accuracy: 0.7907
# Epoch 11/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2652 - accuracy: 0.9062 - val_loss: 0.5007 - val_accuracy: 0.8129
# Epoch 12/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2618 - accuracy: 0.9069 - val_loss: 0.5043 - val_accuracy: 0.8112
# Epoch 13/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2563 - accuracy: 0.9088 - val_loss: 0.5154 - val_accuracy: 0.8090
# Epoch 14/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2485 - accuracy: 0.9120 - val_loss: 0.5422 - val_accuracy: 0.7906
# Epoch 15/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.2442 - accuracy: 0.9122 - val_loss: 0.5206 - val_accuracy: 0.8062
# Epoch 16/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.2397 - accuracy: 0.9142 - val_loss: 0.4994 - val_accuracy: 0.8136
# Epoch 17/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2371 - accuracy: 0.9154 - val_loss: 0.5142 - val_accuracy: 0.8096
# Epoch 18/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.2316 - accuracy: 0.9161 - val_loss: 0.5040 - val_accuracy: 0.8116
# Epoch 19/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.2276 - accuracy: 0.9186 - val_loss: 0.4911 - val_accuracy: 0.8176
# Epoch 20/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.2249 - accuracy: 0.9182 - val_loss: 0.4987 - val_accuracy: 0.8115
# Epoch 21/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2276 - accuracy: 0.9172 - val_loss: 0.4997 - val_accuracy: 0.8135
# Epoch 22/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.2188 - accuracy: 0.9201 - val_loss: 0.4783 - val_accuracy: 0.8214
# Epoch 23/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.2204 - accuracy: 0.9204 - val_loss: 0.4887 - val_accuracy: 0.8180
# Epoch 24/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2184 - accuracy: 0.9207 - val_loss: 0.4994 - val_accuracy: 0.8179
# Epoch 25/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2123 - accuracy: 0.9220 - val_loss: 0.5630 - val_accuracy: 0.7887
# Epoch 26/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2103 - accuracy: 0.9232 - val_loss: 0.4829 - val_accuracy: 0.8212
# Epoch 27/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2046 - accuracy: 0.9264 - val_loss: 0.4807 - val_accuracy: 0.8261
# Epoch 28/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2042 - accuracy: 0.9260 - val_loss: 0.5028 - val_accuracy: 0.8151
# Epoch 29/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.2041 - accuracy: 0.9259 - val_loss: 0.4981 - val_accuracy: 0.8178
# Epoch 30/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.2051 - accuracy: 0.9250 - val_loss: 0.4932 - val_accuracy: 0.8244
# Epoch 31/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.2011 - accuracy: 0.9263 - val_loss: 0.4792 - val_accuracy: 0.8264
# Epoch 32/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.2007 - accuracy: 0.9267 - val_loss: 0.4774 - val_accuracy: 0.8240
# Epoch 33/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.1992 - accuracy: 0.9276 - val_loss: 0.4967 - val_accuracy: 0.8179
# Epoch 34/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.1979 - accuracy: 0.9280 - val_loss: 0.4818 - val_accuracy: 0.8298
# Epoch 35/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.1916 - accuracy: 0.9302 - val_loss: 0.4880 - val_accuracy: 0.8225
# Epoch 36/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.1986 - accuracy: 0.9288 - val_loss: 0.5081 - val_accuracy: 0.8183
# Epoch 37/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.1925 - accuracy: 0.9296 - val_loss: 0.4828 - val_accuracy: 0.8252
# Epoch 38/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.1917 - accuracy: 0.9307 - val_loss: 0.4805 - val_accuracy: 0.8295
# Epoch 39/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.1868 - accuracy: 0.9308 - val_loss: 0.4850 - val_accuracy: 0.8238
# Epoch 40/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.1893 - accuracy: 0.9313 - val_loss: 0.4844 - val_accuracy: 0.8300
# Epoch 41/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.1872 - accuracy: 0.9323 - val_loss: 0.4911 - val_accuracy: 0.8260
# Epoch 42/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.1850 - accuracy: 0.9332 - val_loss: 0.4801 - val_accuracy: 0.8308
# Epoch 43/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.1841 - accuracy: 0.9324 - val_loss: 0.4910 - val_accuracy: 0.8263
# Epoch 44/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.1846 - accuracy: 0.9328 - val_loss: 0.4942 - val_accuracy: 0.8283
# Epoch 45/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.1813 - accuracy: 0.9340 - val_loss: 0.5144 - val_accuracy: 0.8212
# Epoch 46/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.1816 - accuracy: 0.9350 - val_loss: 0.4769 - val_accuracy: 0.8297
# Epoch 47/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.1781 - accuracy: 0.9349 - val_loss: 0.4948 - val_accuracy: 0.8311
# Epoch 48/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.1784 - accuracy: 0.9347 - val_loss: 0.5262 - val_accuracy: 0.8177
# Epoch 49/50
# 493/493 [==============================] - 6s 13ms/step - loss: 0.1783 - accuracy: 0.9362 - val_loss: 0.5047 - val_accuracy: 0.8227
# Epoch 50/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.1763 - accuracy: 0.9367 - val_loss: 0.4940 - val_accuracy: 0.8258

# %%
hist_4_dict = hist_4.history

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(hist_4_dict['loss'], 'b--', label='loss')
plt.plot(hist_4_dict['val_loss'], 'r:', label='val_loss')
plt.xlabel("Epochs")
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(hist_4_dict['accuracy'], 'b--', label='accuracy')
plt.plot(hist_4_dict['val_accuracy'], 'r:', label='val_accuracy')
plt.xlabel("Epochs")
plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# - 학습 인자를 이전과 다르게 주면서 학습하면 더 잘 나올것으로 판단

# %%
model_4.evaluate(x_train, y_train)
# Out:
# 2813/2813 [==============================] - 11s 4ms/step - loss: 0.2080 - accuracy: 0.9277
# [0.20797871053218842, 0.9277111291885376]
